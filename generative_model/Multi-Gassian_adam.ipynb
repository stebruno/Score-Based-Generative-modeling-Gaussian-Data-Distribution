# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import functools
import torch
import functools
from torch.optim import Adam
from torch.utils.data import DataLoader, TensorDataset
from optimizers import THEOPOULA, SGLD
import torchvision.transforms as transforms
from torchvision.datasets import MNIST, CIFAR10
import tqdm
from torchvision.utils import make_grid
import matplotlib.pyplot as plt

# %% [markdown]
# # Forward Process
#
# ### Data distribution:
# $$
# X_0 \sim \pi_D := N(\mu, I_d),
# $$
# for some unknown $\mu \in \mathbb {R}^d$.
#
# ### Forward process:
#
# We consider the following OU process
# $$
# dX_t = -X_t \mathrm d t+ \sqrt{2} \mathrm d W_t.
# $$
# Its solution given $X_0$ can be represented by
# $$
# X_t = m_tX_0  + \sigma_t Z,
# $$
# where
# \begin{align*}
#     m_t &= e^{-t}, \\
#     \sigma_t^2 &= 1- e^{-2t},
# \end{align*}
# and $Z\sim N(0, I_d)$.

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

   
def marginal_prob(t, x):
    t = torch.tensor(t, device=device)
    x = torch.tensor(x, device=device)

    m_t = torch.exp(-t[:, None]) 
    std = torch.sqrt(1 - torch.exp(-2 * t[:, None]))
    
    return m_t, std

def diffusion_drift(t, x):
    t = torch.tensor(t, device=device)    
    x = torch.tensor(x, device=device)
    drift = - x
        
    return drift

def diffusion_coeff(t):
    t = torch.tensor(t, device=device)    
    drift = np.sqrt(2)

    return drift

# %% [markdown]
# # score function
# $$
# \nabla \log p_t(x) = -x + m_t \mu
# $$
# and we consider the approximated score function:
# $$
# s(t, \theta, x) = -x + m_t \theta.
# $$
#
# Furthermore, given the initial sample $x_0$, the corresponding conditional score functions are
# $$
# \nabla \log p_t(x|x_0) = -\frac{x - m_t x_0}{\sigma_t^2}
# $$
#
#
# # Loss function
#
# our objective function is
# \begin{align}
# U(\theta)&:= \mathbb{E}\left[\kappa(\tau) [\| \nabla \log_\tau (X_\tau)- s(\tau, \theta, X_\tau)\|^2] \right]\\
# &=\mathbb{E}\left[\kappa(t) \left \|
#   \sigma_\tau^{-1} Z + s(\tau, \theta, m_\tau X_0 + \sigma_\tau Z) \right\|^2 \right].
# \end{align}
# where $\tau \sim Uni([\epsilon, T])$. In this experiment, we set $\epsilon = 10^{-5}$, $T=1$, and $\kappa(t)=\sigma_t^2$.

# %%
def loss_fn(model, x, marginal_prob, eps=1e-5, T=1):
    random_t = torch.rand(x.shape[0], device=x.device) * (T - eps) + eps  
    z = torch.randn_like(x)
    mean, std = marginal_prob(random_t, x)    

    pt_x = mean * x + z * std
    score = model(random_t, pt_x)
    
    loss = torch.mean(torch.sum((z + std * score)**2, dim=1))    
    return loss

# %%
class Approx_score(nn.Module):
    def __init__(self, input_dim, marginal_prob):
        super(Approx_score, self).__init__()
        self.intput_dim = input_dim
        self.marginal_prob = marginal_prob        
        self.params = nn.Parameter(torch.zeros(input_dim))
        
    def forward(self, t, x):
        mean, std = self.marginal_prob(t, x)
        approx_score = -x + mean * self.params #-(x -  torch.exp(-t[:, None]) * self.params) / std**2
        
        return approx_score

# %% [markdown]
# # Data generation
#
# For visualization, we first consider the case with $d=2$ and each component of $\mu$ is generated from $Uni(-2,2)$.

# %%
input_dim = 2
mu_D = [-1.23486883, -0.89244735]#np.random.rand(2) * 5 - 2.5

print('Unknown mean of the initial data is {}'.format(mu_D))
# Out:
# Unknown mean of the initial data is [-1.23486883, -0.89244735]

# %%
M = 50000
X = mu_D + np.random.randn(M, input_dim)
plt.figure(figsize=(10, 10))
plt.scatter(X[:,0], X[:, 1], c='blue', marker='o')
plt.xlim([-10, 10])
plt.ylim([-10, 10])
plt.grid(True)
#plt.title('initial data')
plt.show()

# %% [markdown]
# # Forward process

# %%
batch_size = 128
n_epochs = 100
lr=5e-5
beta = 1e15
T = 2
eps = 0
optimizer_name = 'ADAM'


X_tensor = torch.from_numpy(X).float().to(device)
dataset = TensorDataset(X_tensor)
data_loader = DataLoader(dataset=dataset, batch_size=batch_size, shuffle=True)

# %%
num_steps = 3
n_rows = 1
time_steps = torch.linspace(0, T, num_steps, device=device)

plt.figure(figsize=(30,10))
for i, t in enumerate(time_steps, 1):
    plt.subplot(n_rows, num_steps/n_rows, i)
    mean_accumulator = []
    for i, data in enumerate(data_loader):
        data = data[0]      
        #print(data.shape, t)
        random_t =  torch.ones(data.shape[0], device=device) * t
        mean, std = marginal_prob(random_t, data)
        Z = torch.randn_like(data)

        Xt = mean * data + std * Z
        Xt = Xt.cpu().numpy()
        
        
        plt.scatter(Xt[:,0], Xt[:, 1], c='blue', marker='o')
        
        
        mean_accumulator.append(Xt)

#     mean_accumulator = np.concatenate(mean_accumulator, axis=0)
#     mean_x = np.mean(mean_accumulator[:,0])
#     mean_y = np.mean(mean_accumulator[:,1])
    
#     print(mean_x, mean_y)
    
    plt.title("t={}".format(t), fontdict={'fontsize':25})
#     plt.plot(np.mean(Xt[:,0]), np.mean(Xt[:,1]), 'ro', markersize=10)
    plt.xlim([-10,10])
    plt.ylim([-10,10])
    plt.grid(True)
        
    plt.xticks(fontsize=20)
    plt.yticks(fontsize=20)
    
plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\anaconda3\envs\py36_cuda\lib\site-packages\ipykernel_launcher.py:7: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   import sys
# C:\Users\user\anaconda3\envs\py36_cuda\lib\site-packages\ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# C:\Users\user\anaconda3\envs\py36_cuda\lib\site-packages\ipykernel_launcher.py:6: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).

# %%
score_model = Approx_score(input_dim, marginal_prob).to(device)

if optimizer_name == 'SGLD':
    optimizer = SGLD(score_model.parameters(), lr=lr, beta=beta)
elif optimizer_name == 'ADAM':
    optimizer = Adam(score_model.parameters(), lr=lr)
history = {'loss': [],
           'params': []          
          }

model_name = 'optimizer{}-epochs{}-bs{}-lr{}-eps{}-beta{:.1e}.pt'.format(optimizer_name, n_epochs, batch_size, lr, eps, beta)

# %%
num_steps =  1000
eps = 0
sample_batch_size = 100000

def Euler_Maruyama_sampler(score_model, 
                           marginal_prob,
                           diffusion_drift,
                           diffusion_coeff, 
                           batch_size,
                           num_steps=num_steps, 
                           device='cuda', 
                           eps=eps,
                           T=T):
    
    t = torch.ones(batch_size, device=device)
    init_x = torch.randn(batch_size, input_dim, device=device)    
    time_steps = torch.linspace(T, eps, num_steps, device=device)
    step_size = time_steps[0] - time_steps[1]
    x = init_x
    
 
    with torch.no_grad():
        for time_step in time_steps:            
            #print(time_step)
            batch_time_step = torch.ones(x.shape[0], device=device) * time_step
      
            mean_x = x + (x + 2 * score_model(batch_time_step, x)) * step_size
            
            
            x = mean_x + torch.sqrt(2 * step_size) * torch.randn_like(x)               
  
    return mean_x

# %%
def compute_ass4(score_model, 
                 marginal_prob,
                 diffusion_drift,
                 diffusion_coeff, 
                 batch_size,
                 num_steps=num_steps, 
                 device='cuda', 
                 eps=eps,
                 T=T):
    
    t = torch.ones(batch_size, device=device)
    init_x = torch.randn(batch_size, input_dim, device=device)    
    time_steps = torch.linspace(T, eps, num_steps, device=device)
    step_size = time_steps[0] - time_steps[1]
    x = init_x
    
    error4 = 0
    with torch.no_grad():
        for time_step in time_steps:            
            #print(time_step)
            batch_time_step = torch.ones(x.shape[0], device=device) * time_step
      
            mean_x = x + (x + 2 * score_model(batch_time_step, x)) * step_size
            
            
            x = mean_x + torch.sqrt(2 * step_size) * torch.randn_like(x)     
            mu_D_tensor = torch.tensor(mu_D, device='cuda')                
            
            error4_t = (- x + torch.exp(-(T-batch_time_step).unsqueeze(-1)) * mu_D_tensor - score_model((T-batch_time_step), x))**2            
            error4 = error4 + error4_t
            
 
    return error4.mean(1).mean() * step_size

# %%
#train하면 comment 해제
score_model = Approx_score(input_dim, marginal_prob).to(device)
hist = {'epoch':[], 'loss':[], 'fid':[], 'error4':[]}
if optimizer_name == 'SGLD':
    optimizer = SGLD(score_model.parameters(), lr=lr, beta=beta)
elif optimizer_name == 'ADAM':
    optimizer = Adam(score_model.parameters(), lr=lr)
history = {'loss': [],
           'params': []        
          }

best_loss = 999
for epoch in range(n_epochs):
    total_loss = 0
    num_items = 0
    
    for i, data in enumerate(data_loader):        
        data = data[0]        
        loss = loss_fn(score_model, data, marginal_prob, eps=eps, T=T)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * data.shape[0]
        num_items += data.shape[0]
    
    print('epoch{}- loss: {:5f}, estimated params:{}'.format(epoch, total_loss/num_items, score_model.params.data))
    history['params'].append(score_model.params.data)
    history['loss'].append(total_loss/num_items)
    
    params = score_model.params.data.cpu().numpy()
    error = np.sum((mu_D - params)**2)
    loss = total_loss/num_items
    
    if best_loss > loss:
        best_loss = loss
        best_params = params
        best_model = score_model.state_dict()        
        model_name = './save/optimizer{}-epochs{}-bs{}-lr{}-eps{}-beta{:.1e}-epoch{}.pt'.format(optimizer_name, n_epochs, batch_size, lr, eps, beta, epoch)
        
        
        samples = Euler_Maruyama_sampler(score_model, 
                  marginal_prob,
                  diffusion_drift,
                  diffusion_coeff, 
                  sample_batch_size,                   
                  device=device,
                  eps = eps,
                  T=T)
        samples = samples.cpu().numpy()#.clamp(0.0, 1.0)  
        
        error4 = compute_ass4(score_model, 
                  marginal_prob,
                  diffusion_drift,
                  diffusion_coeff, 
                  sample_batch_size,                   
                  device=device,
                  eps = eps,
                  T=T)
        error4 = error4.cpu().numpy()
        #fid = np.sqrt((mu_D[0] - samples[:, 0].mean())**2 + (mu_D[1] - samples[:, 1].mean())**2 )
        torch.save(best_model, model_name)
        hist['epoch'].append(epoch)
        hist['loss'].append(loss)
        hist['error4'].append(error4)
        hist['fid'].append(error)
        print(epoch, best_loss, error4, error, best_params)
# Out:
# C:\Users\user\anaconda3\envs\py36_cuda\lib\site-packages\ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# C:\Users\user\anaconda3\envs\py36_cuda\lib\site-packages\ipykernel_launcher.py:6: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# epoch0- loss: 0.754884, estimated params:tensor([-0.0191, -0.0191], device='cuda:0')
# 0 0.7548835050582886 0.5510838 2.2408062645091755 [-0.01909445 -0.01912099]
# epoch1- loss: 0.749760, estimated params:tensor([-0.0383, -0.0381], device='cuda:0')
# 1 0.7497603048896789 0.5316061 2.161608680227583 [-0.03831919 -0.03811859]
# epoch2- loss: 0.745125, estimated params:tensor([-0.0576, -0.0570], device='cuda:0')
# 2 0.7451253683280945 0.5125311 2.084042679380641 [-0.05757966 -0.05696373]
# epoch3- loss: 0.732443, estimated params:tensor([-0.0764, -0.0759], device='cuda:0')
# 3 0.7324426363182068 0.494023 2.0087885102030203 [-0.07641288 -0.07588852]
# epoch4- loss: 0.723007, estimated params:tensor([-0.0953, -0.0943], device='cuda:0')
# 4 0.7230068626403808 0.47603175 1.9356317108429146 [-0.09533326 -0.09426792]
# epoch5- loss: 0.712537, estimated params:tensor([-0.1139, -0.1126], device='cuda:0')
# 5 0.7125368301010132 0.45858723 1.864701202075587 [-0.11391578 -0.11259771]
# epoch6- loss: 0.706028, estimated params:tensor([-0.1327, -0.1308], device='cuda:0')
# 6 0.706027554359436 0.44140425 1.7948313628280386 [-0.13269405 -0.13084239]
# epoch7- loss: 0.699042, estimated params:tensor([-0.1514, -0.1492], device='cuda:0')
# 7 0.6990421965026855 0.4245862 1.7264428839599613 [-0.15136969 -0.14916241]
# epoch8- loss: 0.693636, estimated params:tensor([-0.1700, -0.1673], device='cuda:0')
# 8 0.6936362860488892 0.4081776 1.6597243719698223 [-0.17001063 -0.16732572]
# epoch9- loss: 0.685074, estimated params:tensor([-0.1886, -0.1853], device='cuda:0')
# 9 0.6850736491584778 0.39219835 1.594748933882913 [-0.18861942 -0.18526201]
# epoch10- loss: 0.674433, estimated params:tensor([-0.2071, -0.2032], device='cuda:0')
# 10 0.6744325674629211 0.3766155 1.5313877423941131 [-0.20709915 -0.20318888]
# epoch11- loss: 0.672927, estimated params:tensor([-0.2256, -0.2214], device='cuda:0')
# 11 0.6729271760940552 0.36125863 1.468943295600659 [-0.22559667 -0.2213937 ]
# epoch12- loss: 0.656974, estimated params:tensor([-0.2439, -0.2393], device='cuda:0')
# 12 0.6569743620872498 0.34642276 1.4086182038879895 [-0.243919   -0.23927307]
# epoch13- loss: 0.654916, estimated params:tensor([-0.2625, -0.2571], device='cuda:0')
# 13 0.654916017742157 0.33181375 1.3492143077398335 [-0.26247293 -0.25710452]
# epoch14- loss: 0.644242, estimated params:tensor([-0.2808, -0.2747], device='cuda:0')
# 14 0.6442417803192139 0.317704 1.2918416429485569 [-0.28079927 -0.27471527]
# epoch15- loss: 0.640519, estimated params:tensor([-0.2992, -0.2928], device='cuda:0')
# 15 0.6405191153717041 0.30371273 1.234952124508462 [-0.29923904 -0.29282328]
# epoch16- loss: 0.623230, estimated params:tensor([-0.3174, -0.3102], device='cuda:0')
# 16 0.623229940366745 0.29038012 1.1807388631410518 [-0.31741363 -0.31019756]
# epoch17- loss: 0.630177, estimated params:tensor([-0.3358, -0.3278], device='cuda:0')
# epoch18- loss: 0.618531, estimated params:tensor([-0.3540, -0.3452], device='cuda:0')
# 18 0.6185306645011902 0.26449385 1.0754804088067864 [-0.3539869  -0.34515637]
# epoch19- loss: 0.609620, estimated params:tensor([-0.3721, -0.3623], device='cuda:0')
# 19 0.6096197907066345 0.25219122 1.0254536410049067 [-0.37206426 -0.36233234]
# epoch20- loss: 0.607652, estimated params:tensor([-0.3903, -0.3797], device='cuda:0')
# 20 0.6076524753761291 0.2400632 0.9761404288509774 [-0.39033517 -0.37970635]
# epoch21- loss: 0.599800, estimated params:tensor([-0.4087, -0.3973], device='cuda:0')
# 21 0.599800219707489 0.2281783 0.9278142927237352 [-0.40867192 -0.39725754]
# epoch22- loss: 0.594408, estimated params:tensor([-0.4268, -0.4143], device='cuda:0')
# 22 0.5944080577373505 0.21681428 0.8816056906004595 [-0.42677087 -0.41434342]
# epoch23- loss: 0.595752, estimated params:tensor([-0.4451, -0.4315], device='cuda:0')
# epoch24- loss: 0.597372, estimated params:tensor([-0.4631, -0.4485], device='cuda:0')
# epoch25- loss: 0.577868, estimated params:tensor([-0.4811, -0.4651], device='cuda:0')
# 25 0.5778684625339509 0.18461785 0.7506897944222162 [-0.4811404  -0.46514973]
# epoch26- loss: 0.580445, estimated params:tensor([-0.4993, -0.4821], device='cuda:0')
# epoch27- loss: 0.579728, estimated params:tensor([-0.5175, -0.4985], device='cuda:0')
# epoch28- loss: 0.564089, estimated params:tensor([-0.5350, -0.5153], device='cuda:0')
# 28 0.5640888484382629 0.15544493 0.6320677055120301 [-0.5349887 -0.5153061]
# epoch29- loss: 0.565705, estimated params:tensor([-0.5528, -0.5317], device='cuda:0')
# epoch30- loss: 0.556402, estimated params:tensor([-0.5702, -0.5479], device='cuda:0')
# 30 0.5564015671348572 0.13782507 0.5604217032072449 [-0.57024795 -0.54791754]
# epoch31- loss: 0.556473, estimated params:tensor([-0.5884, -0.5639], device='cuda:0')
# epoch32- loss: 0.553249, estimated params:tensor([-0.6063, -0.5801], device='cuda:0')
# 32 0.5532486113262176 0.12115491 0.4926383902770839 [-0.6063332 -0.5800672]
# epoch33- loss: 0.545722, estimated params:tensor([-0.6240, -0.5960], device='cuda:0')
# 33 0.545721942358017 0.113380186 0.46102447851650985 [-0.6240111 -0.5960063]
# epoch34- loss: 0.544198, estimated params:tensor([-0.6417, -0.6119], device='cuda:0')
# 34 0.5441982235527039 0.105875485 0.4305090327182025 [-0.64172304 -0.61193514]
# epoch35- loss: 0.540494, estimated params:tensor([-0.6592, -0.6275], device='cuda:0')
# 35 0.5404937393951416 0.09876965 0.4016149315574583 [-0.6591942 -0.6274688]
# epoch36- loss: 0.538004, estimated params:tensor([-0.6767, -0.6418], device='cuda:0')
# 36 0.5380040245819092 0.092065156 0.3743537885009436 [-0.6767149 -0.6418122]
# epoch37- loss: 0.533398, estimated params:tensor([-0.6939, -0.6566], device='cuda:0')
# 37 0.5333983064079285 0.08563934 0.34822516290928296 [-0.69392407 -0.6566425 ]
# epoch38- loss: 0.530157, estimated params:tensor([-0.7113, -0.6713], device='cuda:0')
# 38 0.5301567396450043 0.07944926 0.3230550629396286 [-0.7112849 -0.6712802]
# epoch39- loss: 0.529856, estimated params:tensor([-0.7282, -0.6853], device='cuda:0')
# 39 0.5298561969566346 0.07368472 0.2996155360294319 [-0.728221   -0.68526745]
# epoch40- loss: 0.520575, estimated params:tensor([-0.7453, -0.6996], device='cuda:0')
# 40 0.5205754654026031 0.06809793 0.27689853774963125 [-0.7452667  -0.69960475]
# epoch41- loss: 0.518911, estimated params:tensor([-0.7626, -0.7127], device='cuda:0')
# 41 0.5189113569545746 0.06280738 0.2553861338064805 [-0.7625548 -0.7127097]
# epoch42- loss: 0.519228, estimated params:tensor([-0.7798, -0.7259], device='cuda:0')
# epoch43- loss: 0.516758, estimated params:tensor([-0.7968, -0.7388], device='cuda:0')
# 43 0.516757521352768 0.053012133 0.21555687206620897 [-0.7967575 -0.7387745]
# epoch44- loss: 0.514491, estimated params:tensor([-0.8134, -0.7507], device='cuda:0')
# 44 0.5144910922050476 0.04862476 0.1977169055466208 [-0.81342   -0.7506807]
# epoch45- loss: 0.522927, estimated params:tensor([-0.8303, -0.7620], device='cuda:0')
# epoch46- loss: 0.514060, estimated params:tensor([-0.8466, -0.7731], device='cuda:0')
# 46 0.5140604783248901 0.040579982 0.16500544379824142 [-0.8465954  -0.77307737]
# epoch47- loss: 0.509929, estimated params:tensor([-0.8629, -0.7830], device='cuda:0')
# 47 0.5099290216445923 0.036977135 0.1503555941339814 [-0.8628794  -0.78299665]
# epoch48- loss: 0.500816, estimated params:tensor([-0.8791, -0.7933], device='cuda:0')
# 48 0.5008155520439148 0.03354042 0.1363813102246902 [-0.879117  -0.7933416]
# epoch49- loss: 0.502427, estimated params:tensor([-0.8951, -0.8031], device='cuda:0')
# epoch50- loss: 0.501043, estimated params:tensor([-0.9112, -0.8125], device='cuda:0')
# epoch51- loss: 0.501905, estimated params:tensor([-0.9270, -0.8201], device='cuda:0')
# epoch52- loss: 0.501322, estimated params:tensor([-0.9425, -0.8273], device='cuda:0')
# epoch53- loss: 0.499805, estimated params:tensor([-0.9578, -0.8355], device='cuda:0')
# 53 0.4998052667045593 0.019678736 0.0800173742248084 [-0.95778877 -0.8354911 ]
# epoch54- loss: 0.497032, estimated params:tensor([-0.9729, -0.8410], device='cuda:0')
# 54 0.49703188063621523 0.017532522 0.07129035954884431 [-0.97287196 -0.84098864]
# epoch55- loss: 0.501740, estimated params:tensor([-0.9870, -0.8472], device='cuda:0')
# epoch56- loss: 0.499677, estimated params:tensor([-1.0019, -0.8538], device='cuda:0')
# epoch57- loss: 0.493576, estimated params:tensor([-1.0158, -0.8584], device='cuda:0')
# 57 0.49357563804626464 0.012088381 0.049153516891098065 [-1.0158004 -0.8583516]
# epoch58- loss: 0.498792, estimated params:tensor([-1.0297, -0.8633], device='cuda:0')
# epoch59- loss: 0.494578, estimated params:tensor([-1.0426, -0.8671], device='cuda:0')
# epoch60- loss: 0.491969, estimated params:tensor([-1.0549, -0.8696], device='cuda:0')
# 60 0.49196895097732546 0.008092865 0.032907024644593524 [-1.0549047  -0.86964524]
# epoch61- loss: 0.497211, estimated params:tensor([-1.0680, -0.8722], device='cuda:0')
# epoch62- loss: 0.493146, estimated params:tensor([-1.0799, -0.8752], device='cuda:0')
# epoch63- loss: 0.493278, estimated params:tensor([-1.0910, -0.8772], device='cuda:0')
# epoch64- loss: 0.491197, estimated params:tensor([-1.1021, -0.8788], device='cuda:0')
# 64 0.4911969912338257 0.0043799514 0.017809671274201366 [-1.102115   -0.87880546]
# epoch65- loss: 0.498719, estimated params:tensor([-1.1128, -0.8803], device='cuda:0')
# epoch66- loss: 0.488059, estimated params:tensor([-1.1231, -0.8828], device='cuda:0')
# 66 0.48805902738571166 0.0030954329 0.012586578512654935 [-1.1230956 -0.8827866]
# epoch67- loss: 0.489808, estimated params:tensor([-1.1328, -0.8840], device='cuda:0')
# epoch68- loss: 0.491390, estimated params:tensor([-1.1416, -0.8852], device='cuda:0')
# epoch69- loss: 0.489414, estimated params:tensor([-1.1492, -0.8867], device='cuda:0')
# epoch70- loss: 0.494860, estimated params:tensor([-1.1567, -0.8879], device='cuda:0')
# epoch71- loss: 0.492354, estimated params:tensor([-1.1637, -0.8877], device='cuda:0')
# epoch72- loss: 0.486055, estimated params:tensor([-1.1691, -0.8884], device='cuda:0')
# 72 0.4860547994804382 0.0010688056 0.004345949802493277 [-1.1690706  -0.88838005]
# epoch73- loss: 0.489833, estimated params:tensor([-1.1751, -0.8892], device='cuda:0')
# epoch74- loss: 0.494671, estimated params:tensor([-1.1801, -0.8904], device='cuda:0')
# epoch75- loss: 0.488563, estimated params:tensor([-1.1846, -0.8908], device='cuda:0')
# epoch76- loss: 0.497183, estimated params:tensor([-1.1893, -0.8906], device='cuda:0')
# epoch77- loss: 0.496017, estimated params:tensor([-1.1929, -0.8907], device='cuda:0')
# epoch78- loss: 0.491215, estimated params:tensor([-1.1961, -0.8906], device='cuda:0')
# epoch79- loss: 0.492176, estimated params:tensor([-1.1996, -0.8906], device='cuda:0')
# epoch80- loss: 0.491798, estimated params:tensor([-1.2021, -0.8907], device='cuda:0')
# epoch81- loss: 0.496455, estimated params:tensor([-1.2046, -0.8908], device='cuda:0')
# epoch82- loss: 0.493692, estimated params:tensor([-1.2071, -0.8914], device='cuda:0')
# epoch83- loss: 0.491958, estimated params:tensor([-1.2074, -0.8913], device='cuda:0')
# epoch84- loss: 0.487522, estimated params:tensor([-1.2093, -0.8918], device='cuda:0')
# epoch85- loss: 0.491347, estimated params:tensor([-1.2113, -0.8907], device='cuda:0')
# epoch86- loss: 0.492241, estimated params:tensor([-1.2128, -0.8927], device='cuda:0')
# epoch87- loss: 0.489814, estimated params:tensor([-1.2141, -0.8932], device='cuda:0')
# epoch88- loss: 0.486498, estimated params:tensor([-1.2140, -0.8938], device='cuda:0')
# epoch89- loss: 0.493628, estimated params:tensor([-1.2139, -0.8942], device='cuda:0')
# epoch90- loss: 0.491455, estimated params:tensor([-1.2156, -0.8930], device='cuda:0')
# epoch91- loss: 0.486883, estimated params:tensor([-1.2150, -0.8934], device='cuda:0')
# epoch92- loss: 0.488883, estimated params:tensor([-1.2163, -0.8937], device='cuda:0')
# epoch93- loss: 0.492102, estimated params:tensor([-1.2180, -0.8946], device='cuda:0')
# epoch94- loss: 0.489334, estimated params:tensor([-1.2178, -0.8945], device='cuda:0')
# epoch95- loss: 0.489328, estimated params:tensor([-1.2183, -0.8933], device='cuda:0')
# epoch96- loss: 0.486911, estimated params:tensor([-1.2184, -0.8927], device='cuda:0')
# epoch97- loss: 0.492169, estimated params:tensor([-1.2203, -0.8922], device='cuda:0')
# epoch98- loss: 0.486789, estimated params:tensor([-1.2200, -0.8931], device='cuda:0')
# epoch99- loss: 0.491303, estimated params:tensor([-1.2194, -0.8918], device='cuda:0')

# %%
plt.plot(hist['loss'], hist['fid'], label='error')
plt.gca().invert_xaxis()

x_values = np.linspace(min(hist['loss']), max(hist['loss']), 100)
sqrt_values =  5*(x_values)
plt.plot(x_values, sqrt_values, label='reference linear line', linestyle='--')

#plt.plot(x_values, x_values, label='y = x', linestyle='--')

plt.legend()
plt.xlabel('denosing score matching loss')
plt.ylabel(r'$W_2(\mathcal{L}(Y_K^{\mathrm{EM}}), \pi_D)$')
# Out:
# Text(0, 0.5, '$W_2(\\mathcal{L}(Y_K^{\\mathrm{EM}}), \\pi_D)$')

# %%
plt.plot(hist['error4'], hist['fid'], label='error')
plt.gca().invert_xaxis()

x_values = np.linspace(min(hist['error4']), max(hist['error4']), 100)
sqrt_values = 4 * x_values + 0.2
plt.plot(x_values, sqrt_values, label='reference linear line', linestyle='--')

#plt.plot(x_values, x_values, label='y = x', linestyle='--')

plt.legend()
plt.xlabel('Error (Assumption 4)')
plt.ylabel(r'$W_2(\mathcal{L}(Y_K^{\mathrm{EM}}), \pi_D)$')
# Out:
# Text(0, 0.5, '$W_2(\\mathcal{L}(Y_K^{\\mathrm{EM}}), \\pi_D)$')

# %%
print('Unknown mean of the initial data is {}'.format(mu_D))
print('estimated parameter \theta:{}'.format(best_params))
# Out:
# Unknown mean of the initial data is [-1.23486883, -0.89244735]
# estimated parameter 	heta:[-1.1690706  -0.88838005]

# %% [markdown]
# # Sampling reverse SDE
#
# The reverse SDE
# $$
# \mathrm{d} Y_t =  (Y_t+ 2 \nabla \log p_{T-t}(Y_t) )\mathrm{d}t  + \sqrt{2}\mathrm{d}B_t
# $$
# since we approximate the score function as $s(t, \theta^*, x)$, we sample the following SDE:
# $$
# \mathrm{d} Y_t =  (Y_t+ 2 s(T-t,\theta^*,Y_t) )\mathrm{d}t  + \sqrt{2}\mathrm{d}B_t.
# $$
#
#
# Euler-Maruyama approximation:
# $$
# Y_{k+1}^{EM} = Y_{k}^{EM} + \gamma (Y_{k}^{EM}+ 2 s(T-t,\theta^*,Y_{k}^{EM}) ) + \sqrt{2\gamma}Z_{k+1}.
# $$

# %% [markdown]
# # Generated samples

# %%
T
# Out:
# 2

# %%
ckpt = torch.load(model_name, map_location=device)
score_model.load_state_dict(ckpt)

sample_batch_size = 100000

samples = Euler_Maruyama_sampler(score_model, 
                  marginal_prob,
                  diffusion_drift,
                  diffusion_coeff, 
                  sample_batch_size,                   
                  device=device,
                  eps = eps,
                  T=T)
samples = samples.cpu().numpy()#.clamp(0.0, 1.0)


plt.figure(figsize=(10, 10))
plt.scatter(samples[:,0], samples[:, 1], c='blue', marker='o')
plt.xlim([-10,10])
plt.ylim([-10,10])
plt.grid(True)
#plt.title('generated data')
plt.show()
# Out:
# C:\Users\user\anaconda3\envs\py36_cuda\lib\site-packages\ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# C:\Users\user\anaconda3\envs\py36_cuda\lib\site-packages\ipykernel_launcher.py:6: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).

# %%
print(samples[:, 0].mean(), samples[:, 1].mean())
# Out:
# -1.2106698 -0.88649654

# %%
np.sqrt((mu_D[0] - samples[:, 0].mean())**2 + (mu_D[1] - samples[:, 1].mean())**2 )
# Out:
# 0.024920017636388177

# %%
num_steps = 3
n_rows = 1
plt.figure(figsize=(30,10))
time_steps = torch.linspace(0, T, num_steps, device=device)

for i, t in enumerate(time_steps, 1):
    plt.subplot(n_rows, num_steps/n_rows, i)
    
    samples = Euler_Maruyama_sampler(score_model, 
                  marginal_prob,
                  diffusion_drift,
                  diffusion_coeff, 
                  sample_batch_size,                   
                  device=device,
                  eps = eps,
                  T=t if t>0 else eps )
    samples = samples.cpu().numpy()
    plt.scatter(samples[:,0], samples[:, 1], c='blue', marker='o')
    
    plt.title("t={}".format(t), fontdict={'fontsize':25})
    plt.xlim([-10,10])
    plt.ylim([-10,10])
    plt.grid(True)
        
    plt.xticks(fontsize=20)
    plt.yticks(fontsize=20)
    
plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\anaconda3\envs\py36_cuda\lib\site-packages\ipykernel_launcher.py:7: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   import sys
# C:\Users\user\anaconda3\envs\py36_cuda\lib\site-packages\ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# C:\Users\user\anaconda3\envs\py36_cuda\lib\site-packages\ipykernel_launcher.py:6: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).

# %% [markdown]
# # Multivariate normality test
# - Mardia's multivariate normality test
#
#
# I got p-value = 0.564535, thus we cannot reject the null hypothesis. That is, the generated data is reasonably consistent with the hypothesis of a multivariate normal distribution.
